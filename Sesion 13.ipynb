# %% [markdown]
# # Teorema del limite central

# %% [markdown]
# La suma de n variables aleatorias independientes, con un n > 30 tiende a una distribución normal o la curva de campana incluso si las variables aleatorias originales no se distribuyen como una normal

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy.stats import expon, uniform

# %%
poblacion = pd.DataFrame()
poblacion['numbers'] = expon.rvs(40, size=100000)

# %%
poblacion['numbers'].hist(bins=100)

# %%
muestra_promedio = []

tamano = 5000

for i in range(tamano):
    muestra_promedio.append(poblacion.sample(n=100).mean().values[0])

# %%
fig, ax = plt.subplots()
ax.hist(muestra_promedio, bins=50, alpha=0.5)
ax.set(xlabel='Valor promedio', ylabel='Frecuencia')
ax.grid()
